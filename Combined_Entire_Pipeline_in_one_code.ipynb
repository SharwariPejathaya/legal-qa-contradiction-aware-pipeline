# %%
# !pip install textstat spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting textstat
#   Downloading textstat-0.7.12-py3-none-any.whl.metadata (15 kB)
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: nltk in c:\users\home\anaconda3\lib\site-packages (from textstat) (3.9.1)
# Requirement already satisfied: setuptools in c:\users\home\anaconda3\lib\site-packages (from textstat) (72.1.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\home\anaconda3\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\home\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\home\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\home\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\home\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\home\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\home\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\home\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\home\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\home\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\home\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\home\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\home\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\home\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\home\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt in c:\users\home\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\home\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: joblib in c:\users\home\anaconda3\lib\site-packages (from nltk->textstat) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\home\anaconda3\lib\site-packages (from nltk->textstat) (2024.11.6)
# Downloading textstat-0.7.12-py3-none-any.whl (176 kB)
# Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 3.4 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/14.2 MB 3.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.1/14.2 MB 3.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.1/14.2 MB 4.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.9/14.2 MB 4.0 MB/s eta 0:00:03
#    ------------- -------------------------- 4.7/14.2 MB 4.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.8/14.2 MB 4.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.3/14.2 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 7.1/14.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.1/14.2 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 8.9/14.2 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.0/14.2 MB 4.0 MB/s eta 0:00:02
#    ------------------------------ --------- 10.7/14.2 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 11.5/14.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.6/14.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.4/14.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 4.0 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl (25 kB)
# Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl (117 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl (653 kB)
#    ---------------------------------------- 0.0/653.1 kB ? eta -:--:--
#    ---------------------------------------- 653.1/653.1 kB 3.6 MB/s eta 0:00:00
# Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.5 MB/s eta 0:00:00
# Downloading blis-1.3.3-cp313-cp313-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/6.2 MB 5.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.2 MB 4.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.2 MB 4.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 4.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 4.0 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.21.1-py3-none-any.whl (47 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 4.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, smart-open, pyphen, murmurhash, cymem, cloudpathlib, catalogue, blis, typer-slim, srsly, preshed, textstat, confection, weasel, thinc, spacy
#
#    ----------------------------------------  0/18 [wasabi]
#    ---- -----------------------------------  2/18 [spacy-legacy]
#    -------- -------------------------------  4/18 [pyphen]
#    --------------- ------------------------  7/18 [cloudpathlib]
#    ---------------------- ----------------- 10/18 [typer-slim]
#    ------------------------ --------------- 11/18 [srsly]
#    ------------------------ --------------- 11/18 [srsly]
#    -------------------------- ------------- 12/18 [preshed]
#    ---------------------------- ----------- 13/18 [textstat]
#    --------------------------------- ------ 15/18 [weasel]
#    ----------------------------------- ---- 16/18 [thinc]
#    ----------------------------------- ---- 16/18 [thinc]
#    ----------------------------------- ---- 16/18 [thinc]
#    ----------------------------------- ---- 16/18 [thinc]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ------------------------------------- -- 17/18 [spacy]
#    ---------------------------------------- 18/18 [spacy]
#
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.12 pyphen-0.17.2 smart-open-7.5.0 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 textstat-0.7.12 thinc-8.3.10 typer-slim-0.21.1 wasabi-1.1.3 weasel-0.4.3
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 3.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/12.8 MB 4.1 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.1 MB/s eta 0:00:03
#      --------- ------------------------------ 2.9/12.8 MB 4.0 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.7/12.8 MB 3.9 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 4.0 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.8 MB 4.1 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 4.0 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 4.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.3/12.8 MB 3.7 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.7 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 3.7 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 3.6 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 3.6 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.0/12.8 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.5/12.8 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import textstat
import spacy
import re
import ast
import subprocess

# %%
class RobustClassifier:
    def __init__(self):
        try:
            self.nlp = spacy.load("en_core_web_sm")
        except:
            subprocess.run(
                ["python", "-m", "spacy", "download", "en_core_web_sm"],
                stdout=subprocess.DEVNULL,
                stderr=subprocess.DEVNULL
            )
            self.nlp = spacy.load("en_core_web_sm")

        self.sequential_markers = {
            'first', 'second', 'then', 'next',
            'finally', 'subsequently', 'lastly'
        }

        self.second_person_pronouns = {
            'you', 'your', 'yours', 'yourself'
        }

        self.action_verbs = {
            'apply', 'file', 'submit', 'contact', 'visit',
            'obtain', 'provide', 'ensure', 'check', 'verify',
            'prepare', 'complete', 'sign', 'consult', 'appeal'
        }

        self.legal_terms = {
            'act', 'section', 'clause', 'article', 'amendment',
            'statute', 'regulation', 'ordinance', 'provision',
            'code', 'law', 'rule', 'court', 'tribunal'
        }

        self.citation_patterns = [
            r'\b(section|sec\.?|s\.?)\s*\d+',
            r'\b(article|art\.?)\s*\d+',
            r'\b\d{4}\s*act\b',
            r'\b[A-Z]{2,}\s+Act\b'
        ]

    def _analyze_sentence_types(self, doc):
        st = {'imperative': 0, 'declarative': 0, 'interrogative': 0}
        for sent in doc.sents:
            root = sent.root
            if sent.text.strip().endswith('?'):
                st['interrogative'] += 1
            elif root.pos_ == 'VERB' and root.tag_ == 'VB':
                if not any(c.dep_ in ['nsubj', 'nsubjpass'] for c in root.children):
                    st['imperative'] += 1
            else:
                st['declarative'] += 1
        return st

    def normalize_score(self, raw):
        return int(min(raw * 1.6, 100))

    def predict(self, text, extracted_entities):
        doc = self.nlp(text)
        wc = len([t for t in doc if not t.is_punct and not t.is_space])
        if wc == 0:
            return "Inf:0 | Act:0"

        legal_citations = sum(
            len(re.findall(p, text, re.I))
            for p in self.citation_patterns
        )

        entity_count = len(extracted_entities)
        num_count = sum(
            1 for t in doc if t.like_num or t.pos_ == 'NUM'
        )

        inf_density = (
            (legal_citations * 3) +
            (entity_count * 2) +
            num_count
        ) / wc * 100

        entity_legal_bonus = sum(
            1 for e in extracted_entities
            if any(t in e.lower() for t in self.legal_terms)
        )

        action_count = 0
        for t in doc:
            if t.tag_ == 'MD':
                action_count += 2
            if t.lower_ in self.second_person_pronouns:
                action_count += 1
            if t.lemma_ in self.action_verbs:
                action_count += 2

        for m in self.sequential_markers:
            if m in text.lower():
                action_count += 1

        act_density = action_count / wc * 100

        st = self._analyze_sentence_types(doc)
        total = sum(st.values())
        imp_ratio = st['imperative'] / total if total else 0
        dec_ratio = st['declarative'] / total if total else 0

        raw_inf = (inf_density * 2.0) + (dec_ratio * 20) + (entity_legal_bonus * 5)
        raw_act = (act_density * 1.5) + (imp_ratio * 30)

        return f"Inf:{self.normalize_score(raw_inf)} | Act:{self.normalize_score(raw_act)}"

# %%
def extract_scores(score_string):
    inf = int(re.search(r'Inf:(\d+)', score_string).group(1))
    act = int(re.search(r'Act:(\d+)', score_string).group(1))
    return inf, act

def readability_score(text):
    return textstat.flesch_reading_ease(text)

# %%
df = pd.read_csv("vidhikarya_cleaned_for_pipeline.csv")

# %%
def parse_answers(x):
    if pd.isna(x):
        return []

    if isinstance(x, list):
        return x

    text = str(x)

    # IMPORTANT: split on |||
    if "|||" in text:
        return [a.strip() for a in text.split("|||") if a.strip()]

    # fallback
    if text.strip().startswith("["):
        try:
            return ast.literal_eval(text)
        except:
            pass

    return [text.strip()]

# %%
classifier = RobustClassifier()
rows = []

for i, (_, row) in enumerate(df.iterrows()):
    if i % 100 == 0:
        print(f"Processed {i} rows")

    question = row["question"]
    answers = parse_answers(row["updated_answers"])

    if len(answers) == 0:
        continue

    scored = []

    for ans in answers:
        score_str = classifier.predict(ans, [])
        inf, act = extract_scores(score_str)
        read = readability_score(ans)

        scored.append({
            "answer": ans,
            "inf": inf,
            "act": act,
            "read": read
        })

    # THESE LINES MUST BE INSIDE THE LOOP
    best_inf = max(scored, key=lambda x: x["inf"])
    best_act = max(scored, key=lambda x: x["act"])
    best_read = max(scored, key=lambda x: x["read"])

    rows.append({
        "query": question,
        "all_answers": " || ".join(answers),

        "best_informative_answer": best_inf["answer"],
        "best_informative_score": best_inf["inf"],

        "best_actionable_answer": best_act["answer"],
        "best_actionable_score": best_act["act"],

        "best_readable_answer": best_read["answer"],
        "best_readable_score": best_read["read"],
    })
# Out:
# Processed 0 rows
# Processed 100 rows
# Processed 200 rows
# Processed 300 rows
# Processed 400 rows
# Processed 500 rows
# Processed 600 rows
# Processed 700 rows
# Processed 800 rows
# Processed 900 rows
# Processed 1000 rows
# Processed 1100 rows
# Processed 1200 rows
# Processed 1300 rows
# Processed 1400 rows
# Processed 1500 rows
# Processed 1600 rows
# Processed 1700 rows
# Processed 1800 rows
# Processed 1900 rows
# Processed 2000 rows
# Processed 2100 rows
# Processed 2200 rows
# Processed 2300 rows
# Processed 2400 rows
# Processed 2500 rows
# Processed 2600 rows
# Processed 2700 rows
# Processed 2800 rows
# Processed 2900 rows
# Processed 3000 rows
# Processed 3100 rows
# Processed 3200 rows
# Processed 3300 rows
# Processed 3400 rows
# Processed 3500 rows
# Processed 3600 rows
# Processed 3700 rows
# Processed 3800 rows
# Processed 3900 rows
# Processed 4000 rows
# Processed 4100 rows
# Processed 4200 rows
# Processed 4300 rows
# Processed 4400 rows
# Processed 4500 rows
# Processed 4600 rows
# Processed 4700 rows
# Processed 4800 rows
# Processed 4900 rows
# Processed 5000 rows
# Processed 5100 rows
# Processed 5200 rows
# Processed 5300 rows
# Processed 5400 rows
# Processed 5500 rows
# Processed 5600 rows
# Processed 5700 rows
# Processed 5800 rows
# Processed 5900 rows
# Processed 6000 rows
# Processed 6100 rows
# Processed 6200 rows
# Processed 6300 rows
# Processed 6400 rows
# Processed 6500 rows
# Processed 6600 rows
# Processed 6700 rows
# Processed 6800 rows
# Processed 6900 rows
# Processed 7000 rows
# Processed 7100 rows
# Processed 7200 rows
# Processed 7300 rows
# Processed 7400 rows
# Processed 7500 rows
# Processed 7600 rows
# Processed 7700 rows
# Processed 7800 rows
# Processed 7900 rows
# Processed 8000 rows
# Processed 8100 rows
# Processed 8200 rows
# Processed 8300 rows
# Processed 8400 rows
# Processed 8500 rows
# Processed 8600 rows
# Processed 8700 rows
# Processed 8800 rows
# Processed 8900 rows
# Processed 9000 rows
# Processed 9100 rows
# Processed 9200 rows
# Processed 9300 rows
# Processed 9400 rows
# Processed 9500 rows
# Processed 9600 rows
# Processed 9700 rows
# Processed 9800 rows
# Processed 9900 rows
# Processed 10000 rows
# Processed 10100 rows
# Processed 10200 rows
# Processed 10300 rows
# Processed 10400 rows
# Processed 10500 rows
# Processed 10600 rows
# Processed 10700 rows
# Processed 10800 rows
# Processed 10900 rows
# Processed 11000 rows
# Processed 11100 rows
# Processed 11200 rows
# Processed 11300 rows
# Processed 11400 rows
# Processed 11500 rows
# Processed 11600 rows
# Processed 11700 rows
# Processed 11800 rows
# Processed 11900 rows
# Processed 12000 rows
# Processed 12100 rows
# Processed 12200 rows
# Processed 12300 rows
# Processed 12400 rows
# Processed 12500 rows
# Processed 12600 rows
# Processed 12700 rows
# Processed 12800 rows
# Processed 12900 rows
# Processed 13000 rows
# Processed 13100 rows
# Processed 13200 rows
# Processed 13300 rows
# Processed 13400 rows
# Processed 13500 rows
# Processed 13600 rows
# Processed 13700 rows
# Processed 13800 rows
# Processed 13900 rows
# Processed 14000 rows
# Processed 14100 rows
# Processed 14200 rows
# Processed 14300 rows
# Processed 14400 rows
# Processed 14500 rows
# Processed 14600 rows
# Processed 14700 rows
# Processed 14800 rows
# Processed 14900 rows
# Processed 15000 rows
# Processed 15100 rows
# Processed 15200 rows
# Processed 15300 rows
# Processed 15400 rows
# Processed 15500 rows
# Processed 15600 rows
# Processed 15700 rows
# Processed 15800 rows
# Processed 15900 rows
# Processed 16000 rows
# Processed 16100 rows
# Processed 16200 rows
# Processed 16300 rows
# Processed 16400 rows
# Processed 16500 rows
# Processed 16600 rows
# Processed 16700 rows
# Processed 16800 rows
# Processed 16900 rows
# Processed 17000 rows
# Processed 17100 rows
# Processed 17200 rows
# Processed 17300 rows
# Processed 17400 rows
# Processed 17500 rows
# Processed 17600 rows
# Processed 17700 rows
# Processed 17800 rows
# Processed 17900 rows
# Processed 18000 rows
# Processed 18100 rows
# Processed 18200 rows
# Processed 18300 rows
# Processed 18400 rows
# Processed 18500 rows
# Processed 18600 rows
# Processed 18700 rows
# Processed 18800 rows
# Processed 18900 rows
# Processed 19000 rows
# Processed 19100 rows
# Processed 19200 rows
# Processed 19300 rows
# Processed 19400 rows
# Processed 19500 rows
# Processed 19600 rows
# Processed 19700 rows
# Processed 19800 rows
# Processed 19900 rows
# Processed 20000 rows
# Processed 20100 rows
# Processed 20200 rows
# Processed 20300 rows
# Processed 20400 rows
# Processed 20500 rows
# Processed 20600 rows
# Processed 20700 rows
# Processed 20800 rows
# Processed 20900 rows
# Processed 21000 rows
# Processed 21100 rows
# Processed 21200 rows
# Processed 21300 rows
# Processed 21400 rows
# Processed 21500 rows
# Processed 21600 rows
# Processed 21700 rows
# Processed 21800 rows
# Processed 21900 rows
# Processed 22000 rows
# Processed 22100 rows
# Processed 22200 rows
# Processed 22300 rows
# Processed 22400 rows
# Processed 22500 rows
# Processed 22600 rows
# Processed 22700 rows
# Processed 22800 rows
# Processed 22900 rows
# Processed 23000 rows
# Processed 23100 rows
# Processed 23200 rows
# Processed 23300 rows
# Processed 23400 rows
# Processed 23500 rows
# Processed 23600 rows
# Processed 23700 rows
# Processed 23800 rows
# Processed 23900 rows
# Processed 24000 rows
# Processed 24100 rows
# Processed 24200 rows
# Processed 24300 rows
# Processed 24400 rows
# Processed 24500 rows
# Processed 24600 rows
# Processed 24700 rows
# Processed 24800 rows
# Processed 24900 rows
# Processed 25000 rows
# Processed 25100 rows
# Processed 25200 rows
# Processed 25300 rows
# Processed 25400 rows
# Processed 25500 rows
# Processed 25600 rows
# Processed 25700 rows
# Processed 25800 rows
# Processed 25900 rows
# Processed 26000 rows
# Processed 26100 rows
# Processed 26200 rows
# Processed 26300 rows
# Processed 26400 rows
# Processed 26500 rows
# Processed 26600 rows
# Processed 26700 rows
# Processed 26800 rows
# Processed 26900 rows
# Processed 27000 rows
# Processed 27100 rows
# Processed 27200 rows
# Processed 27300 rows
# Processed 27400 rows
# Processed 27500 rows
# Processed 27600 rows
# Processed 27700 rows
# Processed 27800 rows
# Processed 27900 rows
# Processed 28000 rows
# Processed 28100 rows
# Processed 28200 rows
# Processed 28300 rows
# Processed 28400 rows
# Processed 28500 rows
# Processed 28600 rows
# Processed 28700 rows
# Processed 28800 rows
# Processed 28900 rows
# Processed 29000 rows
# Processed 29100 rows
# Processed 29200 rows
# Processed 29300 rows
# Processed 29400 rows
# Processed 29500 rows
# Processed 29600 rows
# Processed 29700 rows
# Processed 29800 rows
# Processed 29900 rows
# Processed 30000 rows
# Processed 30100 rows
# Processed 30200 rows
# Processed 30300 rows
# Processed 30400 rows
# Processed 30500 rows
# Processed 30600 rows
# Processed 30700 rows
# Processed 30800 rows
# Processed 30900 rows
# Processed 31000 rows
# Processed 31100 rows
# Processed 31200 rows
# Processed 31300 rows
# Processed 31400 rows
# Processed 31500 rows
# Processed 31600 rows
# Processed 31700 rows
# Processed 31800 rows
# Processed 31900 rows
# Processed 32000 rows
# Processed 32100 rows
# Processed 32200 rows
# Processed 32300 rows
# Processed 32400 rows
# Processed 32500 rows
# Processed 32600 rows
# Processed 32700 rows
# Processed 32800 rows
# Processed 32900 rows
# Processed 33000 rows
# Processed 33100 rows
# Processed 33200 rows
# Processed 33300 rows
# Processed 33400 rows
# Processed 33500 rows
# Processed 33600 rows
# Processed 33700 rows
# Processed 33800 rows
# Processed 33900 rows
# Processed 34000 rows
# Processed 34100 rows
# Processed 34200 rows
# Processed 34300 rows
# Processed 34400 rows
# Processed 34500 rows
# Processed 34600 rows
# Processed 34700 rows
# Processed 34800 rows
# Processed 34900 rows
# Processed 35000 rows
# Processed 35100 rows
# Processed 35200 rows
# Processed 35300 rows
# Processed 35400 rows
# Processed 35500 rows
# Processed 35600 rows
# Processed 35700 rows
# Processed 35800 rows
# Processed 35900 rows
# Processed 36000 rows
# Processed 36100 rows
# Processed 36200 rows
# Processed 36300 rows
# Processed 36400 rows
# Processed 36500 rows
# Processed 36600 rows
# Processed 36700 rows
# Processed 36800 rows
# Processed 36900 rows
# Processed 37000 rows
# Processed 37100 rows
# Processed 37200 rows
# Processed 37300 rows
# Processed 37400 rows
# Processed 37500 rows
# Processed 37600 rows
# Processed 37700 rows
# Processed 37800 rows

# %%
final_df = pd.DataFrame(rows)
final_df.to_csv("final_legal_answer_selection.csv", index=False)

from google.colab import files
files.download("final_legal_answer_selection.csv")

# %%
final_df = pd.DataFrame(rows)
final_df.to_csv("final_legal_answer_selection.csv", index=False)

# %%
total_rows = len(df)
non_null = df["updated_answers"].notna().sum()

parsed_non_empty = sum(
    1 for x in df["updated_answers"]
    if len(parse_answers(x)) > 0
)

print("Total rows:", total_rows)
print("Rows with non-null updated_answers:", non_null)
print("Rows with parsed answers:", parsed_non_empty)
# Out:
# Total rows: 37945
# Rows with non-null updated_answers: 37381
# Rows with parsed answers: 37381

# %%
print("Length of df used in loop:", len(df))
df.head()
# Out:
# Length of df used in loop: 37945
#                       Category  \
# 0                     Property
# 1  Corporate and Incorporation
# 2                     Property
# 3                     Property
# 4                     Property
#
#                                         Sub Category  \
# 0                      Balcony extension with Camera
# 1                   Salary not credited from 2 month
# 2                D FORM PATTA SURVEY NUMBERS CHANGED
# 3  Urgent Help Needed – Apartment Maintenance Issues
# 4  Clarification on Transfer of Shares, Release d...
#
#                            location  \
# 0             ( Pune, Maharashtra )
# 1          ( Mangalore, Karnataka )
# 2       ( Krishna, Andhra Pradesh )
# 3          ( Hyderabad, Telangana )
# 4  ( Mumbai suburban, Maharashtra )
#
#                                             question  \
# 0  Some flat owners in my society have extended t...
# 1  How can i get my salary with legal procedure( ...
# 2  Dear sir\n                   This is bring to ...
# 3  Subject- Urgent Help Needed – Apartment Mainte...
# 4  We are 3 siblings. Our mother is owner of 2 fl...
#
#                                              answers Number of Ans  \
# 0  Dear Client,If other floor owners extended the...             1
# 1  Dear Client,Your query is too insufficient to ...             1
# 2  Dear Client,To correct errors in Patta, the ow...             1
# 3  Dear client,Based on your situation, it's clea...             3
# 4  Dear Client,Since your mother passed away with...             3
#
#                                                 Link  \
# 0  https://www.vidhikarya.com/FreeLegalAdvice/655...
# 1  https://www.vidhikarya.com/FreeLegalAdvice/655...
# 2  https://www.vidhikarya.com/FreeLegalAdvice/655...
# 3  https://www.vidhikarya.com/FreeLegalAdvice/655...
# 4  https://www.vidhikarya.com/FreeLegalAdvice/655...
#
#                                       advocate_names date_of_question  \
# 0                 Kishan Dutt Kalaskar|||S. K. Dutta      2 weeks ago
# 1                                        S. K. Dutta      2 weeks ago
# 2                 Kishan Dutt Kalaskar|||S. K. Dutta      2 weeks ago
# 3  Kishan Dutt Kalaskar|||Simi Paul|||S. K. Dutta...      2 weeks ago
# 4    Gourab Das|||Kishan Dutt Kalaskar|||S. K. Dutta      2 weeks ago
#
#   date_of_scraping  ... Unnamed: 642 Unnamed: 643 Unnamed: 644 Unnamed: 645  \
# 0       16-06-2025  ...          NaN          NaN          NaN          NaN
# 1       16-06-2025  ...          NaN          NaN          NaN          NaN
# 2       16-06-2025  ...          NaN          NaN          NaN          NaN
# 3       16-06-2025  ...          NaN          NaN          NaN          NaN
# 4       16-06-2025  ...          NaN          NaN          NaN          NaN
#
#   Unnamed: 646 Unnamed: 647 Unnamed: 648 Unnamed: 649 Unnamed: 650  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 651
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 652 columns]

# %%
print("Number of rows written:", len(rows))
# Out:
# Number of rows written: 37381
